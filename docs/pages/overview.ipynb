# %% [raw]
# ---
# title: Overview
# aliases:
#   - ../index.html
# jupyter:
#   kernelspec:
#     display_name: Python 3 (ipykernel)
#     language: python
#     name: python3
# ---

# %% [markdown]
# **tslai** lets you ...
#
# {{< lipsum 1 >}}
#
# ## Installation
#
# ::: {.panel-tabset}
#
# ## pixi
#
# ```bash
# pixi workspace channel add munch-group
# pixi add tslai
# ```
#
# ## conda
#
# ```bash
# conda install -c munch-group tslai
# ```
#
# ## pip
#
# ```bash
# pip install tslai
# ```
#
# :::
#
#
# ## Basic use
#
# ```python
#
# ```
#
# ## Some use case
#
#
# {{< lipsum 1 >}}
